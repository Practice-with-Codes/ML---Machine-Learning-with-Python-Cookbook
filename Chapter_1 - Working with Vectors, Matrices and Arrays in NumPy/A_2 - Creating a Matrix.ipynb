# %% [markdown]
# # A_2: Creating a Matrix

# %%
# Problem Statement: To create a matrix
# Solution: Use NumPy to create a two-dimensional array

# %%
# Load the library

import numpy as np

# %%
# create a matrix

matrix = np.array([[1, 2], 
                  [3, 4], 
                  [4, 5]])

# %%
# print the matrix

print(matrix)
# Out:
# [[1 2]
#  [3 4]
#  [4 5]]

# %%
# References: 
# Matrix, Wikipedia
# Matrix, Wolfram MathWorld

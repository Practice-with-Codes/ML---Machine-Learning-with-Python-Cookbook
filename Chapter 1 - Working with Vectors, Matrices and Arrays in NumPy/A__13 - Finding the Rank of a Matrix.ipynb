# %% [markdown]
# # A13: Finding the Rank of a Matrix

# %%
# Problem Statement: to find the rank of a matrix
# Solution: Use numpy's linear algebra method matrix_rank

# %%
# Load the library

import numpy as np

# %%
# create the matrix

matrix = np.array([[1, 1, 1],
                  [1, 1, 10],
                  [1, 1, 15]])

# %%
# print the matrix

print(matrix)
# Out:
# [[ 1  1  1]
#  [ 1  1 10]
#  [ 1  1 15]]

# %%
# return the ra

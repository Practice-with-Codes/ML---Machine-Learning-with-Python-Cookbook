# %% [markdown]
# # B_6: Loading a Parquet File

# %%
# Problem Statement: To load a parquet file
# Solution: pandas read_parquet allows to read parquet files

# %%
# load the library

import pandas as pd

# %%
import pyarrow as pa

# %%
pip install pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastparquet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas
# Out:
# Requirement already up-to-date: pandas in c:\anaconda3\lib\site-packages (1.3.5)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# create the url

url = 'https://machine-learning-python-cookbook.s3.amazonaws.com/data.parquet'

# %%
# load the data

dataframe = pd.read_parquet(url)

# %%
# view the first two rows

dataframe.head(2)
# Out:
#    integer             datetime  category
# 0        5  2015-01-01 00:00:00         0
# 1        5  2015-01-01 00:00:01         0

# %%
# References: Apache Parquet Documentation

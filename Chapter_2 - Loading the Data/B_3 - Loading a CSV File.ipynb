# %% [markdown]
# # B_3: Loading a CSV File

# %%
# Problem Statement: To import a comma-seperated values (CSV) file
# Solution: Use the pandas library read_csv to load a local or hosted CSV file into a pandas DataFrame

# %%
# load the library

import pandas as pd

# %%
# create the url

url = 'https://raw.githubusercontent.com/chrisalbon/sim_data/master/data.csv'

# %%
# load the dataset

dataframe = pd.read_csv(url)

# %%
# view the first two rows

dataframe.head(2)
# Out:
#    integer             datetime  category
# 0        5  2015-01-01 00:00:00         0
# 1        5  2015-01-01 00:00:01         0

# %%
# able to see how they are structured and what parameters required to load in a file
# read_csv has over 30 parameters

# %%
# CSV files, seperated by commas 
# pandas, sep parameter defines the delimiter used in a file
# header specifies if or where a header row exists
# if header does not exist, set header = None

# %%
# read_csv --> returns pandas dataframe
# common and useful object for working tabular data

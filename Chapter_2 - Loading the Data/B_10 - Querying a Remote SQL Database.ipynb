# %% [markdown]
# # B_10: Querying a Remote SQL Database

# %%
# Problem Statement: To connect to, and read from, a remote SQL database
# Solution: create a connection with pymysql and read it into a dataframe with pandas

# %%
pip install PyMySQL
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries

import pymysql
import pandas as pd

# %%
# create a DB connection
# use the example below to start a DB instance
# https://github.com/kylegallatin/mysql-db-example

# %%
# conn = pymysql.connect(host='localhost',
#                        user='root',
#                       password = "",
#                       db='db', )

# %%
# read the SQL query into a dataframe
dataframe = pd.read_sql("select * from data", conn)

# %%
# view the first 2 rows

dataframe.head(2)

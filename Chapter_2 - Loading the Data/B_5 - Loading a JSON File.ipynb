# %% [markdown]
# # B_5: Loading a JSON File

# %%
# Problem Statement: Load a JSON file for data preprocessing
# Solution: Pandas library provides read_json to covert a jason file to pandas object

# %%
# load the library

import pandas as pd

# %%
# create the url

url = 'https://raw.githubusercontent.com/chrisalbon/sim_data/master/data.json'

# %%
# load the data

dataframe = pd.read_json(url, orient = 'columns')

# %%
# view the first two rows

dataframe.head(2)
# Out:
#    integer            datetime  category
# 0        5 2015-01-01 00:00:00         0
# 1        5 2015-01-01 00:00:01         0

# %%
# orient parameter, indicates to pandas how jason file is structured
# arguments --> split, records, index, columns, values
# jason_normalize - converts semistructured JSON data into pandas dataframe

# %%
# References:
# json_normalize documentation
